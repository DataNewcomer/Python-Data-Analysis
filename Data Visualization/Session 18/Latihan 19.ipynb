# %%
import pandas as pd
import folium

# %% [markdown]
# # 1. Tampilkan lokasi rumah paling mahal di melbourne!
# - Tandai dengan dengan icon pin warna merah,
# - Ketika cursor mouse di-hover ke lokasi akan keluar tulisan 'Rumah' dan kalau diklik akan keluar alamatnya (Address)!

# %%
df_house = pd.read_csv('melb_data.csv')
df_house.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df_house = df_house.sort_values('Price', ascending=False)
df_house
# Out:
#             Suburb           Address  Rooms Type      Price Method  \
# 12094     Mulgrave       35 Bevis St      3    h  9000000.0     PI
# 7692    Canterbury    49 Mangarra Rd      5    h  8000000.0     VB
# 9575      Hawthorn      49 Lisson Gr      4    h  7650000.0      S
# 3616           Kew       15 Barry St      6    h  6500000.0      S
# 12557  Middle Park       136 Page St      5    h  6400000.0      S
# ...            ...               ...    ...  ...        ...    ...
# 7940      Hawthorn     17/17 Park St      1    u   160000.0     VB
# 7303        Albion     8/6 Ridley St      1    u   145000.0     PI
# 1927        Coburg   171 Moreland Rd      4    h   145000.0     PI
# 1805     Caulfield        30 Pyne St      4    h   131000.0     PI
# 2652     Footscray  202/51 Gordon St      1    u    85000.0     PI
#
#             SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 12094          Hall  29/07/2017      18.8    3170.0  ...       1.0  1.0
# ...

# %%
# Melbourne Map
melb_map = folium.Map(
    location=[-37.93168, 145.16126],
    zoom_start=12
)

# Marker
house_marker = folium.Marker(
    location=[-37.93168, 145.16126],
    tooltip='House',
    popup='35 Bevis St Mulgrave VIC 3170, Australia',
    icon = folium.Icon(color='red', icon='home')
)

# Memasukkan Marker kedalam Melbourne Map
melb_map.add_child(house_marker)

melb_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # 2. Andaikan kita sedang mencari apartemen (Type 'u') dengan 2 kamar tidur ('Bedroom2') dan harganya murah
# - Menampilkan peta kota melbourne
# - Berikan marker pada 5 apartemen (Type 'u') termurah dengan 2 kamar tidur
# - Beri keterangan pada popup berupa Suburb dan Alamat ('Address')
# - Beri keterangan pada tooltip berupa harga ('Price')
# - memakai iterrows untuk yang nomor 2 .iterrows()

# %%
df_house_melb = df_house[(df_house['Type']== 'u') & (df_house['Bedroom2']== 2)].sort_values(by= 'Price').head(5)
df_house_melb
# Out:
#          Suburb                Address  Rooms Type     Price Method  \
# 7303     Albion          8/6 Ridley St      1    u  145000.0     PI
# 7305     Albion         5/25 Ridley St      2    u  190000.0     SP
# 5205  Reservoir    1/164 Leamington St      1    u  216000.0      S
# 2915    Glenroy  14/854 Pascoe Vale Rd      2    u  230000.0     PI
# 5221  Reservoir         4/1067 High St      2    u  240000.0     PI
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 7303     Biggin  28/05/2016      13.9    3020.0  ...       1.0  1.0      36.0
# 7305    Burnham  30/07/2016      13.9    3020.0  ...       1.0  1.0       0.0
# 5205       Brad  24/09/2016      11.2    3073.0  ...       1.0  1.0       0.0
# 2915      Raine  18/03/2017      13.0    3046.0  ...       1.0  1.0    1996.0
# 5221  Stockdale  26/07/2016      11.2    3073.0  ...       1.0  1.0      82.0
#
#       BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
# # Hanya menyimpan kolom penting 
# df_house_melb = df_house_melb[["Lattitude", "Longtitude", "Suburb"]]

# # Map
# map = folium.Map(location=[df_house_melb.Latitude.mean(), df_house_melb.Longtitude.mean()], zoom_start=14, control_scale=True)

# # Looping
# for index, location_info in df_house_melb .iterrows():
#     folium.Marker([location_info["Latitude"], location_info["Longtitude"]], popup=location_info["Suburb"]).add_child(map)


# # Hanya menyimpan kolom penting 
# df_house= df_house[["Lattitude", "Longtitude", "Suburb"]]

# # Map
# map = folium.Map(location=[df_house.Lattitude.mean(), df_house.Longtitude.mean()], zoom_start=14, control_scale=True)

# # Looping
# for index, location_info in df_house.iterrows():
#     folium.Marker([location_info["Lattitude"], location_info["Longtitude"]], popup=location_info["Suburb"]).add_to(map)


# map

# Melbourne map
melb_map = folium.Map(
    location=[-37.93168, 145.16126],
    zoom_start=12
)

# Looping
